# %% [markdown]
# # Домашнее задание 2 (5 баллов).
#
# Все задания ниже имеют равный вес (5/16).

# %%
import pandas as pd
from zipfile import ZipFile
import numpy as np

# %% [markdown]
# #### Описание данных
#
# В папке Data находится информация о студентах. Всего 10 групп студентов. Файлы делятся на две категории:
#     * Students_info_i - информация о студентах из группы i
#     * Students_marks_i - оценки студентов из группы i за экзамены

# %%
ZipFile('Data.zip').infolist()
# Out:
# [<ZipInfo filename='Data/' external_attr=0x10>,
#  <ZipInfo filename='Data/Students_info_0.csv' compress_type=deflate external_attr=0x20 file_size=5860 compress_size=717>,
#  <ZipInfo filename='Data/Students_info_1.csv' compress_type=deflate external_attr=0x20 file_size=6022 compress_size=734>,
#  <ZipInfo filename='Data/Students_info_2.csv' compress_type=deflate external_attr=0x20 file_size=5954 compress_size=702>,
#  <ZipInfo filename='Data/Students_info_3.csv' compress_type=deflate external_attr=0x20 file_size=5942 compress_size=713>,
#  <ZipInfo filename='Data/Students_info_4.csv' compress_type=deflate external_attr=0x20 file_size=5979 compress_size=703>,
#  <ZipInfo filename='Data/Students_info_5.csv' compress_type=deflate external_attr=0x20 file_size=6019 compress_size=725>,
#  <ZipInfo filename='Data/Students_info_6.csv' compress_type=deflate external_attr=0x20 file_size=5968 compress_size=705>,
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Одно из важных достоинств pandas $-$ это удобные методы реляционного взаимодействия с данными, аналогичные, например, возможностям SQL для слияния и конкатенации таблиц: merge, join, concat. Наличие готовых методов позволяет не реализовывать самостоятельно поэлементную обработку данных и оперировать сразу целыми таблицами данных.
#
# Подробно об этих методах посмотрите тут: https://www.kaggle.com/residentmario/renaming-and-combining#Combining

# %% [markdown]
# #### Задание 1. Соберите всю информацию о студентах в одну таблицу df. В получившейся таблице должна быть информация и оценки всех студентов из всех групп. Напечатайте несколько строк таблицы для демонстрации результата.¶

# %%
dfs_info = []
dfs_marks = []

for i in range(10):
    name = 'Data/Students_info_' + str(i) + '.csv'
    dfs_info.append(pd.read_csv(ZipFile("Data.zip").open(name)))
    
for i in range(10):
    name = 'Data/Students_marks_' + str(i) + '.csv'
    dfs_marks.append(pd.read_csv(ZipFile("Data.zip").open(name)))

result_info = pd.concat(dfs_info)
result_marks = pd.concat(dfs_marks)
result = pd.merge(result_info, result_marks, how="left")

result # я вывела все для себя, чтобы посмотреть
# Out:
#      index  gender race/ethnicity parental level of education         lunch  \
# 0        0  female        group B           bachelor's degree      standard
# 1        1  female        group C                some college      standard
# 2        2  female        group B             master's degree      standard
# 3        3    male        group A          associate's degree  free/reduced
# 4        4    male        group C                some college      standard
# 5        5  female        group B          associate's degree      standard
# 6        6  female        group B                some college      standard
# 7        7    male        group B                some college  free/reduced
# 8        8    male        group D                 high school  free/reduced
# 9        9  female        group B                 high school  free/reduced
# 10      10    male        group C          associate's degree      standard
# ...

# %%
result.sample(n=5)
# Out:
#      index  gender race/ethnicity parental level of education         lunch  \
# 623    623    male        group A                some college      standard
# 340    340    male        group C                 high school  free/reduced
# 558    558  female        group B          associate's degree  free/reduced
# 103    103    male        group B                 high school      standard
# 183    183  female        group D          associate's degree      standard
#
#     test preparation course   group  math score  reading score  writing score
# 623               completed  group7         100             96             86
# 340                    none  group4          58             61             52
# 558                    none  group6          53             70             70
# 103               completed  group2          60             44             47
# 183                    none  group2          65             69             70

# %% [markdown]
# #### Задание 2. Удалите столбец index у полученной таблицы. Напечатайте первые 10 строк таблицы.

# %%
result = result.drop('index', axis=1)
result.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course   group  math score  reading score  writing score
# 0                    none  group1          72             72             74
# 1               completed  group1          69             90             88
# ...

# %% [markdown]
# #### Задание 3. Выведите на экран размеры полученной таблицы

# %%
print(result.shape)
# Out:
# (1000, 9)

# %% [markdown]
# #### Задание 4. Выведите на экран статистические характеристики числовых столбцов таблицы (минимум, максимум, среднее значение, стандартное отклонение)

# %%
print(result.describe())
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# #### Задание 5. Проверьте, есть ли в таблице пропущенные значения

# %%
print(result.info()) # пропущенные значения отсутсвуют
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   group                        1000 non-null   object
#  6   math score                   1000 non-null   int64
#  7   reading score                1000 non-null   int64
#  8   writing score                1000 non-null   int64
# dtypes: int64(3), object(6)
# memory usage: 78.1+ KB
# None

# %% [markdown]
# #### Задание 6. Выведите на экран средние баллы студентов по каждому предмету (math, reading, writing)

# %%
print(f'''Mean math: {result['math score'].mean()} \nMean reading: {result['reading score'].mean()} \nMean writing: {result['writing score'].mean()}''')
# Out:
# Mean math: 66.089
# Mean reading: 69.169
# Mean writing: 68.054

# %% [markdown]
# **Задание 7. Как зависят оценки от того, проходил ли студент курс для подготовки к сдаче экзамена (test preparation course)? Выведите на экран для каждого предмета в отдельности средний балл студентов, проходивших курс для подготовки к экзамену и не проходивших курс.**

# %%
gr = result.groupby(by="test preparation course")
gr.mean(numeric_only=True)
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                 69.695531      73.893855      74.418994
# none                      64.077882      66.534268      64.504673

# %% [markdown]
# **Задание 8. Выведите на экран все различные значения из столбца lunch.**

# %%
print(set(result['lunch']))
# Out:
# {'standard', 'free/reduced'}

# %% [markdown]
# **Задание 9. Переименуйте колонку "parental level of education" в "education", а "test preparation course" в "test preparation" с помощью метода pandas rename**
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html

# %%
result = result.rename(columns={"parental level of education": "education", "test preparation course": "test preparation"})
result.head()
# Out:
#    gender race/ethnicity           education         lunch test preparation  \
# 0  female        group B   bachelor's degree      standard             none
# 1  female        group C        some college      standard        completed
# 2  female        group B     master's degree      standard             none
# 3    male        group A  associate's degree  free/reduced             none
# 4    male        group C        some college      standard             none
#
#     group  math score  reading score  writing score
# 0  group1          72             72             74
# 1  group1          69             90             88
# 2  group1          90             95             93
# 3  group1          47             57             44
# 4  group1          76             78             75

# %% [markdown]
# **Зафиксируем минимальный балл для сдачи экзамена**

# %%
passmark = 50

# %% [markdown]
# **Задание 10. Ответьте на вопросы:**
#     * Какая доля студентов сдала экзамен по математике (passmark >= 50)?
#     * Какая доля студентов, проходивших курс подготовки к экзамену, сдала экзамен по математике?
#     * Какая доля женщин, не проходивших курс подготовки к экзамену, не сдала экзамен по математике?

# %%
result.loc[result['math score'] >= passmark, 'passmark'] = True
result.loc[result['math score'] <= passmark, 'passmark'] = False
result.head(5)
# Out:
#    gender race/ethnicity           education         lunch test preparation  \
# 0  female        group B   bachelor's degree      standard             none
# 1  female        group C        some college      standard        completed
# 2  female        group B     master's degree      standard             none
# 3    male        group A  associate's degree  free/reduced             none
# 4    male        group C        some college      standard             none
#
#     group  math score  reading score  writing score passmark
# 0  group1          72             72             74     True
# 1  group1          69             90             88     True
# 2  group1          90             95             93     True
# 3  group1          47             57             44    False
# 4  group1          76             78             75     True

# %%
print("Доля студентов, проходивших курс подготовки к экзамену, которая сдала экзамен по математике: ")
print(((result['passmark'].loc[((result['passmark'] == True) & (result['test preparation'] == "completed"))]).size) 
      / (result['passmark'][result['test preparation'] == "completed"]).size)


print("Доля женщин, не проходивших курс подготовки к экзамену, которая не сдала экзамен по математике:")
print(((result['passmark'].loc[((result['gender'] == 'female') & (result['passmark'] == False) 
                                  & (result['test preparation'] == "none"))]).size)
      / (result['passmark'][result['test preparation'] == "none"]).size)
# Out:
# Доля студентов, проходивших курс подготовки к экзамену, которая сдала экзамен по математике:
# 0.9078212290502793
# Доля женщин, не проходивших курс подготовки к экзамену, которая не сдала экзамен по математике:
# 0.12149532710280374

# %% [markdown]
# **Задание 11. С помощью groupby выполните задания ниже. Также выведите время выполнения каждого из заданий.**
#     * Для каждой этнической группы выведите средний балл за экзамен по чтению
#     * Для каждого уровня образования выведите минимальный балл за экзамен по письму

# %%
from datetime import datetime

# %%
now = datetime.now()

gr = result.groupby(by="race/ethnicity")
print(gr['reading score'].mean())

time_execution = datetime.now() - now
print(time_execution)
# Out:
# race/ethnicity
# group A    64.674157
# group B    67.352632
# group C    69.103448
# group D    70.030534
# group E    73.028571
# Name: reading score, dtype: float64
# 0:00:00.004829

# %%
now = datetime.now()

gr = result.groupby(by="education")
print(gr['writing score'].min())


time_execution = datetime.now() - now
print(time_execution)
# Out:
# education
# associate's degree    35
# bachelor's degree     38
# high school           15
# master's degree       46
# some college          19
# some high school      10
# Name: writing score, dtype: int64
# 0:00:00.004855

# %% [markdown]
# **Задание 12. Выполните задание 11 с помощью циклов. Сравните время выполнения.**

# %%
from statistics import mean
now = datetime.now()


for_mean = {'group A': [], 'group B': [], 'group C': [], 'group D': [], 'group E': []}

for ind, i in enumerate(result['race/ethnicity']):
    if i == "group A":
        for_mean['group A'].append(result['reading score'].loc[result.index[ind]])
    elif i == "group B":
        for_mean['group B'].append(result['reading score'].loc[result.index[ind]])
    elif i == "group C":
        for_mean['group C'].append(result['reading score'].loc[result.index[ind]])
    elif i == "group D":
        for_mean['group D'].append(result['reading score'].loc[result.index[ind]])
    else:
        for_mean['group E'].append(result['reading score'].loc[result.index[ind]])


for key, value in for_mean.items():
    print(key, mean(value))
    
time_execution = datetime.now() - now
print(time_execution)
# Out:
# group A 64
# group B 67
# group C 69
# group D 70
# group E 73
# 0:00:00.041000

# %%
now = datetime.now()


for_min = {'associate': [], 'bachelor': [], 'high_school': [], 'master': [], 'some_college': [], 'some_high_school': []}

for ind, i in enumerate(result['education']):
    if i == "associate's degree":
        for_min['associate'].append(result['writing score'].loc[result.index[ind]])
    elif i == "bachelor's degree":
        for_min['bachelor'].append(result['writing score'].loc[result.index[ind]])
    elif i == "high school":
        for_min['high_school'].append(result['writing score'].loc[result.index[ind]])
    elif i == "master's degree":
        for_min['master'].append(result['writing score'].loc[result.index[ind]])
    elif i == "some college":
        for_min['some_college'].append(result['writing score'].loc[result.index[ind]])
    else:
        for_min['some_high_school'].append(result['writing score'].loc[result.index[ind]])


for key, value in for_min.items():
    print(key, min(value))
    
time_execution = datetime.now() - now
print(time_execution)
# Out:
# associate 35
# bachelor 38
# high_school 15
# master 46
# some_college 19
# some_high_school 10
# 0:00:00.043939

# %% [markdown]
# Можно сделать вывод, что с помощью groupby задания выполняются быстрее.

# %% [markdown]
# **Задание 13. Выведите на экран средние баллы студентов по каждому предмету в зависимости от пола и уровня образования. То есть должно получиться количество групп, равных 2 * (число уровней образования), и для каждой такой группы выыведите средний балл по каждому из предметов.**
#
# Это можно сделать с помощью сводных таблиц (pivot_table):
#
# https://www.kaggle.com/kamilpolak/tutorial-how-to-use-pivot-table-in-pandas

# %%
grouped = pd.pivot_table(result,index=['gender','education'],aggfunc={'math score':np.mean,'reading score':np.mean, 
                                                                      'writing score':np.mean})
grouped
# Out:
#                            math score  reading score  writing score
# gender education
# female associate's degree   65.250000      74.120690      74.000000
#        bachelor's degree    68.349206      77.285714      78.380952
#        high school          59.351064      68.202128      66.691489
#        master's degree      66.500000      76.805556      77.638889
#        some college         65.406780      73.550847      74.050847
#        some high school     59.296703      69.109890      68.285714
# male   associate's degree   70.764151      67.433962      65.405660
#        bachelor's degree    70.581818      68.090909      67.654545
#        high school          64.705882      61.480392      58.539216
#        master's degree      74.826087      73.130435      72.608696
#        some college         69.009259      64.990741      63.148148
#        some high school     67.840909      64.693182      61.375000

# %% [markdown]
# #### Задание 14. Сколько студентов успешно сдали экзамен по математике?
#
# Создайте новый столбец в таблице df под названием Math_PassStatus и запишите в него F, если студент не сдал экзамен по математике (балл за экзамен < passmark), и P иначе.
#
# Посчитайте количество студентов, сдавших и не сдавших экзамен по математике.
#
# Сделайте аналогичные шаги для экзаменов по чтению и письму.

# %%
result = result.drop(columns='passmark')

# %%
result.loc[result['math score'] >= passmark, 'Math_PassStatus'] = 'P'
result.loc[result['math score'] < passmark, 'Math_PassStatus'] = 'F'

result.loc[result['reading score'] >= passmark, 'Reading_PassStatus'] = 'P'
result.loc[result['reading score'] < passmark, 'Reading_PassStatus'] = 'F'

result.loc[result['writing score'] >= passmark, 'Writing_PassStatus'] = 'P'
result.loc[result['writing score'] < passmark, 'Writing_PassStatus'] = 'F'

result.head(10)
# Out:
#    gender race/ethnicity           education         lunch test preparation  \
# 0  female        group B   bachelor's degree      standard             none
# 1  female        group C        some college      standard        completed
# 2  female        group B     master's degree      standard             none
# 3    male        group A  associate's degree  free/reduced             none
# 4    male        group C        some college      standard             none
# 5  female        group B  associate's degree      standard             none
# 6  female        group B        some college      standard        completed
# 7    male        group B        some college  free/reduced             none
# 8    male        group D         high school  free/reduced        completed
# 9  female        group B         high school  free/reduced             none
#
#     group  math score  reading score  writing score Math_PassStatus  \
# ...

# %%
gr = result.groupby(by="Math_PassStatus").size()
print(gr)
# Out:
# Math_PassStatus
# F    135
# P    865
# dtype: int64

# %%
gr = result.groupby(by="Reading_PassStatus").size()
print(gr)
# Out:
# Reading_PassStatus
# F     90
# P    910
# dtype: int64

# %%
gr = result.groupby(by="Writing_PassStatus").size()
print(gr)
# Out:
# Writing_PassStatus
# F    114
# P    886
# dtype: int64

# %% [markdown]
# #### Задание 15. Сколько студентов успешно сдали все экзамены?
#
# Создайте столбец OverAll_PassStatus и запишите в него для каждого студента 'F', если студент не сдал хотя бы один из трех экзаменов, а иначе 'P'.
#
# Посчитайте количество студентов, которые сдали все экзамены.

# %%
result.loc[(result['Math_PassStatus'] == 'P') & (result['Reading_PassStatus'] == 'P') & (result['Writing_PassStatus'] == "P"),
           'OverAll_PassStatus'] = 'P'

result.loc[(result['Math_PassStatus'] == 'F') | (result['Reading_PassStatus'] == 'F') | (result['Writing_PassStatus'] == "F"),
           'OverAll_PassStatus'] = 'F'

result.head(10)
# Out:
#    gender race/ethnicity           education         lunch test preparation  \
# 0  female        group B   bachelor's degree      standard             none
# 1  female        group C        some college      standard        completed
# 2  female        group B     master's degree      standard             none
# 3    male        group A  associate's degree  free/reduced             none
# 4    male        group C        some college      standard             none
# 5  female        group B  associate's degree      standard             none
# 6  female        group B        some college      standard        completed
# 7    male        group B        some college  free/reduced             none
# 8    male        group D         high school  free/reduced        completed
# 9  female        group B         high school  free/reduced             none
#
#     group  math score  reading score  writing score Math_PassStatus  \
# ...

# %%
print('количество студентов, которые сдали все экзамены: ')
print(result['OverAll_PassStatus'].loc[(result['OverAll_PassStatus'] == 'P')].size)
# Out:
# количество студентов, которые сдали все экзамены:
# 812

# %% [markdown]
# #### Задание 16. Переведем баллы в оценки
#
# ### Система перевода баллов в оценки
# ####    больше 90 = A
# ####      80-90 = B
# ####      70-80 = C
# ####      60-70 = D
# ####      50-60 = E
# ####    меньше 50 = F (Fail)
#
# Создайте вспомогательную функцию, которая будет по среднему баллу за три экзамена выставлять оценку студенту по данным выше критериям.
#
# Создайте столбец Grade и запишите в него оценку каждого студента.
#
# Выведите количество студентов, получивших каждую из оценок.
#
# **В случае, если средний балл попадает на границу между оценками (т.е. равен ровно 60, 70 или 80 баллов), вы можете интерпретировать условие на своё усмотрение (т.е. можете поставить за 60 баллов оценку D, а можете - E).**

# %%
marks = []
def GetGrade(average_mark):
    if average_mark >= 90:
        marks.append("A")
    elif average_mark >= 80:
        marks.append("B")
    elif average_mark >= 70:
        marks.append("C")
    elif average_mark >= 60:
        marks.append("D")
    elif average_mark > 50:
        marks.append("E")
    else:
        marks.append("F")
        
    
#return 

for i in list((result.mean(axis=1, numeric_only=True))):
    GetGrade(i)

result['Grade'] = marks
result
# Out:
#      gender race/ethnicity           education         lunch test preparation  \
# 0    female        group B   bachelor's degree      standard             none
# 1    female        group C        some college      standard        completed
# 2    female        group B     master's degree      standard             none
# 3      male        group A  associate's degree  free/reduced             none
# 4      male        group C        some college      standard             none
# 5    female        group B  associate's degree      standard             none
# 6    female        group B        some college      standard        completed
# 7      male        group B        some college  free/reduced             none
# 8      male        group D         high school  free/reduced        completed
# 9    female        group B         high school  free/reduced             none
# 10     male        group C  associate's degree      standard             none
# ...
